# %% [markdown]
# <a href="https://colab.research.google.com/github/edenhunsader/breast-cancer-subset/blob/main/Colab_Notebook_Breast_cancer_subset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Procedural Overview
#
# > Below are the steps to filter through the 2017 November data of the SEER Program of the NCI to include only cancer related data points.

# %% [markdown]
# ## Working with raw data

# %% [markdown]
# Import pandas inorder to enable editing of the data file

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Instruct the pandas software to read the csv file containing the data set

# %%
df=pd.read_csv("Breast_Cancer.csv")

# %% [markdown]
# Run a test to double check that the data set was properly run

# %%
df.shape
# Out:
# (4024, 16)

# %%
df[0:5]
# Out:
#    Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0   68  White        Married       T1      N1       IIA
# 1   50  White        Married       T2      N2      IIIA
# 2   58  White       Divorced       T3      N3      IIIC
# 3   58  White        Married       T1      N1       IIA
# 4   47  White        Married       T2      N1       IIB
#
#                differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0      Poorly differentiated     3  Regional           4        Positive
# 1  Moderately differentiated     2  Regional          35        Positive
# 2  Moderately differentiated     2  Regional          63        Positive
# 3      Poorly differentiated     3  Regional          18        Positive
# 4      Poorly differentiated     3  Regional          41        Positive
#
#   Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# 0            Positive                      24                      1
# 1            Positive                      14                      5
# 2            Positive                      14                      7
# 3            Positive                       2                      1
# 4            Positive                       3                      1
#
#    Survival Months Status
# 0               60  Alive
# 1               62  Alive
# 2               75  Alive
# 3               84  Alive
# 4               50  Alive

# %% [markdown]
# ## Narrowing down the data set

# %% [markdown]
# Standardize all demographic information in the categories of age, race, and martial status.

# %% [markdown]
# First find the average value for each of these categories

# %%
df.describe()
# Out:
#                Age   Tumor Size  Regional Node Examined  \
# count  4024.000000  4024.000000             4024.000000
# mean     53.972167    30.473658               14.357107
# std       8.963134    21.119696                8.099675
# min      30.000000     1.000000                1.000000
# 25%      47.000000    16.000000                9.000000
# 50%      54.000000    25.000000               14.000000
# 75%      61.000000    38.000000               19.000000
# max      69.000000   140.000000               61.000000
#
#        Reginol Node Positive  Survival Months
# count            4024.000000      4024.000000
# mean                4.158052        71.297962
# std                 5.109331        22.921430
# min                 1.000000         1.000000
# 25%                 1.000000        56.000000
# 50%                 2.000000        73.000000
# 75%                 5.000000        90.000000
# max                46.000000       107.000000

# %% [markdown]
# Turn the catagorical values into numerical in order to find the average

# %%
# replacing values
df['Race'].replace(['Black', 'White','Other'],
                        [0, 1, 2], inplace=True)

# %%
df['Race'].describe()
# Out:
# count    4024.000000
# mean        1.007207
# std         0.389647
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         2.000000
# Name: Race, dtype: float64

# %% [markdown]
# Now filter out everything but the average age and average race inorder to standardize the data across the demographic categories of age and race.

# %%
df[df['Age'] == 54][df['Race'] == 1]
# Out:
# <ipython-input-46-435876a9a7fd>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Age'] == 54][df['Race'] == 1]
#       Age  Race Marital Status T Stage  N Stage 6th Stage  \
# 36     54     1        Married       T2      N2      IIIA
# 106    54     1        Married       T2      N1       IIB
# 114    54     1        Married       T3      N2      IIIA
# 140    54     1        Married       T1      N1       IIA
# 144    54     1        Married       T2      N1       IIB
# ...   ...   ...            ...      ...     ...       ...
# 3935   54     1        Married       T1      N1       IIA
# 3943   54     1        Single        T2      N1       IIB
# 3964   54     1        Widowed       T1      N1       IIA
# 3987   54     1        Married       T1      N1       IIA
# 4016   54     1        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 36    Moderately differentiated     2  Regional          27        Positive
# 106       Poorly differentiated     3  Regional          40        Positive
# 114   Moderately differentiated     2  Regional          51        Positive
# 140         Well differentiated     1  Regional           7        Positive
# 144   Moderately differentiated     2  Regional          34        Positive
# ...                         ...   ...       ...         ...             ...
# 3935  Moderately differentiated     2  Regional          15        Positive
# 3943      Poorly differentiated     3  Regional          30        Positive
# 3964      Poorly differentiated     3  Regional          12        Negative
# 3987  Moderately differentiated     2  Regional           7        Negative
# 4016        Well differentiated     1  Regional          50        Positive
#
#      Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# 36              Negative                      21                      6
# 106             Negative                      11                      1
# 114             Positive                       6                      5
# 140             Positive                       4                      1
# 144             Positive                      20                      1
# ...                  ...                     ...                    ...
# 3935            Positive                      16                      1
# 3943            Positive                      10                      1
# 3964            Negative                       1                      1
# 3987            Positive                      12                      1
# 4016            Positive                      29                      2
#
#       Survival Months Status
# 36                 37  Alive
# 106                24   Dead
# 114               103  Alive
# 140                86  Alive
# 144                52   Dead
# ...               ...    ...
# 3935               97  Alive
# 3943               59  Alive
# 3964               62  Alive
# 3987               89  Alive
# 4016               52  Alive
#
# [108 rows x 16 columns]

# %% [markdown]
# Because cancer does not differ along the lines of martial status, we do not need to filter that demographic factor out and can remove it all together.

# %%
df.drop ('Marital Status', inplace=True, axis=1)

# %%
df[df['Age'] == 54][df['Race'] == 1]
# Out:
# <ipython-input-48-435876a9a7fd>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Age'] == 54][df['Race'] == 1]
#       Age  Race T Stage  N Stage 6th Stage              differentiate Grade  \
# 36     54     1       T2      N2      IIIA  Moderately differentiated     2
# 106    54     1       T2      N1       IIB      Poorly differentiated     3
# 114    54     1       T3      N2      IIIA  Moderately differentiated     2
# 140    54     1       T1      N1       IIA        Well differentiated     1
# 144    54     1       T2      N1       IIB  Moderately differentiated     2
# ...   ...   ...      ...     ...       ...                        ...   ...
# 3935   54     1       T1      N1       IIA  Moderately differentiated     2
# 3943   54     1       T2      N1       IIB      Poorly differentiated     3
# 3964   54     1       T1      N1       IIA      Poorly differentiated     3
# 3987   54     1       T1      N1       IIA  Moderately differentiated     2
# 4016   54     1       T2      N1       IIB        Well differentiated     1
#
#        A Stage  Tumor Size Estrogen Status Progesterone Status  \
# 36    Regional          27        Positive            Negative
# 106   Regional          40        Positive            Negative
# 114   Regional          51        Positive            Positive
# 140   Regional           7        Positive            Positive
# 144   Regional          34        Positive            Positive
# ...        ...         ...             ...                 ...
# 3935  Regional          15        Positive            Positive
# 3943  Regional          30        Positive            Positive
# 3964  Regional          12        Negative            Negative
# 3987  Regional           7        Negative            Positive
# 4016  Regional          50        Positive            Positive
#
#       Regional Node Examined  Reginol Node Positive  Survival Months Status
# 36                        21                      6               37  Alive
# 106                       11                      1               24   Dead
# 114                        6                      5              103  Alive
# 140                        4                      1               86  Alive
# 144                       20                      1               52   Dead
# ...                      ...                    ...              ...    ...
# 3935                      16                      1               97  Alive
# 3943                      10                      1               59  Alive
# 3964                       1                      1               62  Alive
# 3987                      12                      1               89  Alive
# 4016                      29                      2               52  Alive
#
# [108 rows x 15 columns]

# %% [markdown]
# Label this new data set as "Health_Metrics_subset"

# %%
Health_Metrics_subset = df[df['Age'] == 54][df['Race'] == 1].copy()
# Out:
# <ipython-input-49-d01ad3337dba>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Health_Metrics_subset = df[df['Age'] == 54][df['Race'] == 1].copy()

# %% [markdown]
# Run a test

# %%
Health_Metrics_subset
# Out:
#       Age  Race T Stage  N Stage 6th Stage              differentiate Grade  \
# 36     54     1       T2      N2      IIIA  Moderately differentiated     2
# 106    54     1       T2      N1       IIB      Poorly differentiated     3
# 114    54     1       T3      N2      IIIA  Moderately differentiated     2
# 140    54     1       T1      N1       IIA        Well differentiated     1
# 144    54     1       T2      N1       IIB  Moderately differentiated     2
# ...   ...   ...      ...     ...       ...                        ...   ...
# 3935   54     1       T1      N1       IIA  Moderately differentiated     2
# 3943   54     1       T2      N1       IIB      Poorly differentiated     3
# 3964   54     1       T1      N1       IIA      Poorly differentiated     3
# 3987   54     1       T1      N1       IIA  Moderately differentiated     2
# 4016   54     1       T2      N1       IIB        Well differentiated     1
#
#        A Stage  Tumor Size Estrogen Status Progesterone Status  \
# 36    Regional          27        Positive            Negative
# 106   Regional          40        Positive            Negative
# 114   Regional          51        Positive            Positive
# 140   Regional           7        Positive            Positive
# 144   Regional          34        Positive            Positive
# ...        ...         ...             ...                 ...
# 3935  Regional          15        Positive            Positive
# 3943  Regional          30        Positive            Positive
# 3964  Regional          12        Negative            Negative
# 3987  Regional           7        Negative            Positive
# 4016  Regional          50        Positive            Positive
#
#       Regional Node Examined  Reginol Node Positive  Survival Months Status
# 36                        21                      6               37  Alive
# 106                       11                      1               24   Dead
# 114                        6                      5              103  Alive
# 140                        4                      1               86  Alive
# 144                       20                      1               52   Dead
# ...                      ...                    ...              ...    ...
# 3935                      16                      1               97  Alive
# 3943                      10                      1               59  Alive
# 3964                       1                      1               62  Alive
# 3987                      12                      1               89  Alive
# 4016                      29                      2               52  Alive
#
# [108 rows x 15 columns]

# %% [markdown]
# Download the new subset

# %%
Health_Metrics_subset.to_csv("Health_Metrics_subset.csv", index=False)
